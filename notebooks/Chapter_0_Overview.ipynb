# %% [markdown]
# # Overview

# %% [markdown]
# Welcome to the introductory notebook of the course **5 Minutes to Federated Learning with NVIDIA FLARE**.
#
# In this first overview notebook, we cover the following elements:
# - An overview of the goals, requirements and structure of this course
# - An introduction to Federated Learning
# - What is NVIDIA FLARE, with brief introduction to its core components

# %% [markdown]
# # Course Goals
#
# In this course, our primary goal is to **introduce the fundamentals of NVIDIA FLARE to researchers, scientits and developers**.
#
# This course is considered as a beginer-level course on NVIDIA FLARE, therefore the content is tailored to be on API & tool usage level, without deep diving into too much details of the inner implementations. We do not aim for you to become an NVIDIA FLARE developer after the course, but we do aim to provide you with the knowledge on how to effectively use NVIDIA FLARE's APIs and tools to implement your FL projects. You will hopefully gain the following after the course:
# - Be able to implement FL, by adapting traditional centralized computing / training code to federated paradigm with NVIDIA FLARE APIs.
# - Be able to set up, configure, run and monitor federated applications both in a simulated environment and in a real-world sandbox scenario.
# - Have the high-level knowledge of advanced security features for real-world deployment.
# - Be able to find and access additional learning resource, if you would like have a deeper understanding of NVIDIA FLARE.

# %% [markdown]
# # Course Requirements
#
# Prerequisites of this course include:
# - Python programming skills
# - Basic understanding of machine learning & deep learning
#
# This course contains multiple examples that we will walkthrough and run together. It is helpful to have experiences in machine learning / deep learning libraries such as `numpy`, `pytorch`, but these are not mandatory, as we will only us basic APIs of these SDKs. Regarding hardware, most of the examples can be run on NVIDIA T4 or equivalent GPUs, or even in CPU-only environment. Having more powerful GPUs could help accelerate the compute for some of the examples in this course.

# %% [markdown]
# # Course Structure
#
# This course is broken down into the following 7 notebooks. The first 4 notebooks give an overview of Federated Learning and NVIDIA FLARE, and walk you through NVIDIA FLARE's APIs and tools with hands-on examples and exercises. The last 3 notebooks contains real-world industrial Federated Learning examples using NVIDIA FLARE. While each notebook can run independently, it is recommended to first follow the contents in notebook 1, 2, 3 and 4 in order, to become familiar with NVIDIA FLARE.
#
# ### [Chapter 0: Overview](Chapter_0_Overview.ipynb)
# This notebook gives an overview introduction to Federated Learning and NVIDIA FLARE.
#
# ### [Chapter 1: Introduction to NVDIA FLARE Basic APIs and Simulator](Chapter_1_Intro_APIs_and_Simulator.ipynb)
# In this notebook, we introduce the high-level architecture of NVIDIA FLARE and the basics APIs for federated Server, Client and Job. We illustrate with an example how easily it is to adapt typical compute / training workflows to a federated paradigm using these APIs, and showcase how we can easily run a federated workflow locally in a simulated environment with FLARE Simulator.
#
# ### [Chapter 2: Provisioning, PoC Mode and Minotoring](Chapter_2_Provision_PoC_Mode_and_Monitoring.ipynb)
# In this notebook, we dive in the concept of provisioning in NVIDIA FLARE for properly setting up an FL applications, and demonstrate how to test-run and monitor a provisioned FL application in a local environment, as if in real-world deployment. We illustrate the provision process with an example using Proof-of-Concept (PoC) mode with NVIDIA FLARE.
#
# ### [Chapter 3: Advanced Topics and Additional Learning Resources](Chapter_3_Advanced_Topics_and_Additional_Resources.ipynb)
# In this notebook, we introduce advanced topics in NVIDIA FLARE for real-world FL deployment, including security features such as privacy preserving technologies, site policy management and support for Confidential Computing, web UI with FLARE Dashboard and Federated Large Language Models. We will finish this notebook by providing additional learning resources for developers who aim to learn more about real-world FL deployment with NVIDIA FLARE.
#
# ### [Example 1: Medical Imaging](Example_1_Medical_Imaging.ipynb)
# This notebook includes a real-world example of medical image segmentation using NVIDIA FLARE and the MONAI framework.
#
# ### [Example 2: Fraud Detection in Financial Services](Example_2_Financial_Services_Fraud_Detection.ipynb)
# This notebook includes a real-world example of fraud detection in finanicla services using NVIDIA FLARE.
#
# ### [Example 3: Cross Country Training for Autonomous Vehicles](Example_3_Autonomous_Vehicles_Cross_Country_Training.ipynb)
# This notebook includes a real-world example of cross-country training in autonomous vehicles using NVIDIA FLARE.

# %% [markdown]
# # Motivation and Introduction to Federated Learning

# %% [markdown]
# Building real-world AI applications is challenging: it requires external, multi-institutional and prospective data. A [recent study](https://pmc.ncbi.nlm.nih.gov/articles/PMC6389801/) shows that, amoung 516 pubilished medical AI studies in 2018, only 6% of them performed external validations. Even fewer of these studies included multi-institutional and prospective validation data. Today, getting access to high quality multi-institutional data in traditional machine learning paradigm still poses many challenges in terms of data sharing regulation, legal constraints, privacy concerns, technical considerations etc.
#
# <img src="../images/real-world-ai.png" alt="Real World AI" width=35% height=35% />
#
# Federated Learning (FL) is a distributed machine learning paradigm which potentially solves these data access challenges. In FL, learning occurs at each site locally, with its own local datasets. Instead of centralizing local datasets, a global model is obtained via aggregating locally trained models. Compared with centralized learning, FL enables the creation of commonly robust models while holding multiple benefits:
# - **Enhanced Data Privacy and Security**: FL facilitates data privacy and data locality by ensuring that the data remains at each site. Additionally, privacy preserving techniques such as homomorphic encryption and differential privacy filters can be further leveraged to protect the transferred data.
# - **Improved Model Performance and Diversity**: by training with a variety of external data sources across different clients, a robust and generalizable global model can be developed to better represent heterogeneous data distribution in real-world.
# - **Scalability and Efficiency**: with the ability to perform training locally at the edge, federated learning can be highly scalable across the globe. Additionally, only needing to transfer the model weights rather than entire datasets enables efficient use of resources.
#
# Typically, an FL project would include the following concepts:
# - **FL server**: a central entity that manages job lifecycle, orchestrates the workflow, assigns training / computation tasks to clients and performs aggregation of computation results received from clients.
# - **FL client**: entity representing a local site. A client executes tasks assigned by the FL server, performs local computation / training with local dataset, and submits result back to FL server.
# - **FL workflow**: an FL workflow is a distributed workflow with specific optimization algorithms and communication strategies, which determine how local training / computations are performed and how results aggregation is performed on the server side.
#
# There are various types of FL. In the centralized version of FL, the FL server has the role of the aggregrator node. However, in a decentralized version such as [swarm learning](https://www.nature.com/articles/s41586-021-03583-3), FL clients can serve as the aggregator nodes instead. An FL workflow can be horizontal, in the sense that clients hold different data samples with the same features; while in vertical FL, clients hold different features over an overlapping set of data samples.
#
# <img src="../images/fl-diagram.png" alt="FL centralized" width=50% height=50% />
#
# In a typical centralized FL, the server orchestrates the collaboration of multiple clients by first sending an initial model to the FL clients. The clients perform training on their local datasets, then send the model updates back to the FL server for aggregation to update a global model. This process forms a single round of federated learning and after a number of rounds, a robust global model can be developed. A classic example is the Federated Averaging (FedAvg) algorithm, where the server aggregates the received model updates from clients by performing a weighted average, to obtain the global model. While being a straight-forward algorithm, FedAvg does not account for data heterogeneity amoung different clients. Over recent years, many other federated algorithms have been proposed to better deal with data heterogeneity. Popular ones include FedOpt, FedProx, Scaffold etc.
#
# Today, FL has applications over various industry sectors. For instance, an important application of federated learning is in the healthcare sector, where data privacy regulations and patient record confidentiality make training models challenging. Federated learning can help break down these healthcare data silos to allow hospitals and medical institutions to collaborate and pool their medical knowledge without the need to share their data. Some common use cases involve cancer classification and detection, drug discovery with federated protein large language models, federated analytics of medical devices etc. Furthermore, there are many other areas and industries such as financial fraud detection, autonomous vehicles, HPC, mobile applications, etc., where the ability to use distributed data silos while maintaining data privacy is essential for the development of better models.

# %% [markdown]
# # What is NIVDIA FLARE
#
# Implementing FL is a challenging task. Carefully designed software tools are needed for scientists and developers to quickly and easily prototype an FL project and test its feasibility. Additionally, tools to properly perform project monitoring, experiment tracking and debugging are also needed to effectively design and build FL projects. Also, there are still open research questions regarding the performance of FL in comparison with centralized learning paradigm, especially for heterogeneous data distributions. Implemetation of an FL workflow needs to be flexible enough to account for new distributed optimization algorithms that are constantly being proposed. Next, to build real-world AI leveraging FL, a proper implementation of security and privacy measures is needed. These measures include for instance user authentication, authorization, data encryption and privacy filters etc. Finally, in real-world FL deployment, a production-ready and scalable runtime  environment is also needed to handle aspects such as service high availability (back-up servers), mixture of compute resources and concurrent job executions etc.
#
# NVIDIA Federated Learning Application Runtime Environment (NVIDIA FLARE) was created to tackle all these challenges in implementing FL. NVIDIA FLARE is a domain- & framework-agnostic, open-source, extensible Python SDK that allows researchers and data scientists to easily adapt existing machine / deep learning workflow to a federated paradigm. NVIDIA FLARE SDK is also built for robust and production scale real-world FL deployments. With NVIDIA FLARE, developers can build a secure, privacy preserving offering for a distributed multi-party collaboration.
#
# <img src="../images/nvflare.png" alt="NVFLARE" width=50% height=50% />
#
# Core components of NVIDIA FLARE include:
# - Carefully designed APIs for data scientists and researchers to easily adapt existing computation / training code to a federated paradigm
# - A runtime environment enabling data scientists and researchers to easily carry out FL experiments in a simulated environment, with extensible tools for project monitoring
# - Highly customizable components, with built-in implementations of:
#   - Federated training workflows (scatter-and-gather, cyclic, etc.)
#   - Federated evaluation workflows (global model evaluation, cross site model validation, etc.)
#   - Learning algorithms (FedAvg, FedOpt, FedProx, etc.)
#   - And many more ...
# - A rich set of programmable APIs allowing researchers to create new federated workflows, learning & privacy preserving algorithms
# - Features to bring FL from research to real-world deployment, for example:
#   - Exetensible tools for secure provisioning and orchestration
#   - Production-level runtime for large scale, concurrent multi-task execution
#   - Privacy preserving technologies (homomorphic encryption, differential privacy, ...) and support for Confidential Computing
#   - System capabilities to set up federated learning with high availability infrastructure
#   - And many more ...
#
# <img src="../images/FLARE-platform.jpg" alt="FLARE Platform" width=50% height=50% />

# %% [markdown]
# # Start Learning Now!
#
# Hope this introductory overview has got you excited about Federated Learning and NVIDIA FLARE!
#
# Wait no further, start learning now by jumping straight to [Chapter 1](Chapter_1_Intro_APIs_and_Simulator.ipynb)!
