# %% [markdown]
# ## Provisioning with the FLARE Dashboard

# %%
# !nvflare dashboard -h
# Out:
# usage: nvflare dashboard [-h] [--cloud CLOUD] [--start] [--stop] [-p PORT]
#                          [-f FOLDER] [--passphrase PASSPHRASE] [-e ENV]
#                          [--cred CRED]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --cloud CLOUD         launch dashboard on cloud service provider (ex:
#                         --cloud azure or --cloud aws)
#   --start               start dashboard
#   --stop                stop dashboard
#   -p PORT, --port PORT  port to listen
#   -f FOLDER, --folder FOLDER
#                         folder containing necessary info (default: current
#                         working directory)
#   --passphrase PASSPHRASE
#                         Passphrase to encrypt/decrypt root CA private key. !!!
#                         Do not share it with others. !!!
#   -e ENV, --env ENV     additonal environment variables: var1=value1
#   --cred CRED           set credential directly in the form of
#                         USER_EMAIL:PASSWORD

# %% [markdown]
# The FL Dashboard stores files in the current working directory by default, or in a specific directory provided in the `-f FOLDER` argument.  This is convenient for preserving the dashboard state when stopping and restarting the dashboard.
#
# We'll use `/tmp/fl-dashboard` directory for this example (necessary for running the container within the lab container).

# %%
# !if [ ! -d /tmp/fl-dashboard ]; then mkdir /tmp/fl-dashboard; else echo "/tmp/fl-dashboard directory already exists."; fi

# %% [markdown]
# ### Running the FL Dashboard
# The FL Dashboard runs in a minimal Docker container with the web UI accessible on port 443 by default.  This port can be changed with the `-p PORT` arg.  We'll used 4443 in this example.
#
# The `--start` and `--stop` arguments can be used to start and stop the Dashboard container.  Let's start it.  In the output, you'll see confirmation of the email used for admin credentials along with the temporary password.  Remember this email/password combination, especially if you plan to stop and restart the dashboard.

# %%
# !printf '%s\n' user@nvidia.com | nvflare dashboard -f /tmp/fl-dashboard -p 4443 --start
# Out:
# Please provide project admin email address.  This person will be the super user of the dashboard and this project.
# generating random password
# Project admin credential is user@nvidia.com and the password is wJgma6kO
# Pulling nvflare/nvflare, may take some time to finish.
# Launching nvflare/nvflare
# Dashboard will listen to port 4443
# /tmp/fl-dashboard on host mounted to /var/tmp/nvflare/dashboard in container
# environment vars set to {'NVFL_CREDENTIAL': 'user@nvidia.com:wJgma6kO'}
# Dashboard container started
# Container name nvflare-dashboard
# id is 6d1ce2b678606030ebc95e21aa71db7af4ecbc7bb0e9747742a2bf0389da1db0

# %% [markdown]
# ### FL Dashboard UI
# When the dashboard is up and running, you can access it by opening a browser to <URL:4443 HERE>

# %% [markdown]
# When you're done with the FL Dashboard, stop it by running:

# %%
# !nvflare dashboard --stop
# Out:
# nvflare-dashboard exited
